# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.8 MB 2.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/10.8 MB 3.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/10.8 MB 3.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/10.8 MB 3.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/10.8 MB 4.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/10.8 MB 6.3 MB/s eta 0:00:02
#    -------- ------------------------------- 2.2/10.8 MB 7.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.3/10.8 MB 8.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.6/10.8 MB 10.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.1/10.8 MB 12.9 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import panel as pn

pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
df=pd.read_json('C:\\Users\\alokknight\\blackcoffer\\VisualizationDashBoardServer\\jsondata.json')

# %%
df
# Out:
#     end_year intensity              sector        topic  \
# 0                    6              Energy          gas
# 1                    6              Energy          oil
# 2                    6              Energy  consumption
# 3                    6         Environment          oil
# 4                    6                           market
# ..       ...       ...                 ...          ...
# 995                  2  Financial services          oil
# 996     2016                 Manufacturing       growth
# 997                 16                           growth
# 998     2016         3              Retail       export
# 999                  2
#
#                                                insight  \
# 0                                Annual Energy Outlook
# 1                                Annual Energy Outlook
# 2                                Annual Energy Outlook
# 3    WRI Partnership Aims to Foster Supply Chain Tr...
# ...

# %%
df.columns
# Out:
# Index(['end_year', 'intensity', 'sector', 'topic', 'insight', 'url', 'region',
#        'start_year', 'impact', 'added', 'published', 'country', 'relevance',
#        'pestle', 'source', 'title', 'likelihood'],
#       dtype='object')

# %%
df.dtypes
# Out:
# end_year      object
# intensity     object
# sector        object
# topic         object
# insight       object
# url           object
# region        object
# start_year    object
# impact        object
# added         object
# published     object
# country       object
# relevance     object
# pestle        object
# source        object
# title         object
# likelihood    object
# dtype: object

# %%
df= df.drop(columns=['title','url',])

# %%
df.columns
# Out:
# Index(['end_year', 'intensity', 'sector', 'topic', 'insight', 'region',
#        'start_year', 'impact', 'added', 'published', 'country', 'relevance',
#        'pestle', 'source', 'likelihood'],
#       dtype='object')

# %%
df['topic'].unique()
# Out:
# array(['gas', 'oil', 'consumption', 'market', 'gdp', 'war', 'production',
#        'export', 'battery', '', 'biofuel', 'policy', 'economy',
#        'strategy', 'robot', 'growth', 'economic', 'energy', 'food',
#        'administration', 'unemployment', 'trade', 'demand',
#        'economic growth', 'industry', 'capital', 'worker', 'tension',
#        'terrorism', 'transport', 'peak oil', 'vehicle', 'tourist',
#        'artificial intelligence', 'climate', 'power', 'crisis', 'ice',
#        'population', 'politics', 'business', 'work', 'coal',
#        'gamification', 'finance', 'interest rate', 'risk', 'inflation',
#        'asylum', 'resource', 'plastic', 'electricity', 'bank', 'gasoline',
#        'car', 'money', 'technology', 'aquaculture', 'city', 'investment',
#        'revenue', 'emission', 'climate change', 'infrastructure',
#        'government', 'security', 'software', 'building', 'transportation',
#        'wealth', 'clothing', 'shortage', 'debt', 'agriculture', 'tax',
# ...

# %% [markdown]
# 1:  Trends Over Time

# %%
df['end_year'] = pd.to_numeric(df['end_year'], errors='coerce')
df['start_year'] = pd.to_numeric(df['start_year'], errors='coerce')

# %%
year_data = df[['end_year', 'start_year']]

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Descriptive statistics
year_data.describe()

# Line plot for trends over time
year_data.plot(kind='line', figsize=(10, 6))
# Out:
# <Axes: >

# %%
import matplotlib as plt
# df.set_index('end_year', inplace=True)

# Create line plots
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.plot(df.index, df['intensity'])
plt.title('Intensity Over Time')

plt.subplot(2, 2, 2)
plt.plot(df.index, df['impact'])
plt.title('Impact Over Time')

plt.subplot(2, 2, 3)
plt.plot(df.index, df['relevance'])
plt.title('Relevance Over Time')

plt.subplot(2, 2, 4)
plt.plot(df.index, df['likelihood'])
plt.title('Likelihood Over Time')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\alokknight\blackcoffer\VisualizationDashBoardServer\vis.ipynb Cell 15 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/alokknight/blackcoffer/VisualizationDashBoardServer/vis.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/alokknight/blackcoffer/VisualizationDashBoardServer/vis.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> # df.set_index('end_year', inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/alokknight/blackcoffer/VisualizationDashBoardServer/vis.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/alokknight/blackcoffer/VisualizationDashBoardServer/vis.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> # Create line plots
# ...
